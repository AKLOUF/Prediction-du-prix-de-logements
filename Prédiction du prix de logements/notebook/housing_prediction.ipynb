# %%
(contenu minimal)
{
"cells": [
  {
   "celltype": "markdown",
   "source": [
    "# Housing Price Prediction\n",
    "Notebook for testing and exploring the model."
   ]
  }
],
"metadata": {
  "kernelspec": { "displayname": "Python 3", "language": "python", "name": "python3" }
},
"nbformat": 4,
"nbformat_minor": 2
}
